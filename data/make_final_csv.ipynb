# %% [markdown]
# # import library

# %%
import pandas as pd

# %% [markdown]
# # Category csv handling

# %%
df = pd.read_csv('./bag_image_csv/choco_categories_categories.csv')

# %%
df
# Out:
#       id  shape  strap  opening_type  material  color  pattern  handle  \
# 0     17      2      2             5         3      7       99       2
# 1     18      5      1             5         1     10       99       2
# 2     19      3      2             5         1     11       99       2
# 3     20      1      4             1         2      4        6      99
# 4     21      1      2             5         1     12       99       2
# ..   ...    ...    ...           ...       ...    ...      ...     ...
# 697  714      3      3             1         0     11        2       2
# 698  715      1      3             1         1      7       99       4
# 699  716      9      1             1         1     14       99       4
# 700  717      1      4             5         0      5       99       0
# 701  718      4      3             1         1     11        1       4
#
#      version  decoration  cropped_image_id
# 0          2           4                75
# 1          2           4                76
# 2          2          99                77
# 3          2           4                78
# 4          2           6                79
# ..       ...         ...               ...
# 697        2           2               745
# 698        2           2               746
# 699        2           2               747
# 700        2           2               748
# 701        2          99               749
#
# [702 rows x 11 columns]

# %%
## 중복 제거

df = df.drop_duplicates(['cropped_image_id'])

# %%
df
# Out:
#       id  shape  strap  opening_type  material  color  pattern  handle  \
# 0     17      2      2             5         3      7       99       2
# 1     18      5      1             5         1     10       99       2
# 2     19      3      2             5         1     11       99       2
# 3     20      1      4             1         2      4        6      99
# 4     21      1      2             5         1     12       99       2
# ..   ...    ...    ...           ...       ...    ...      ...     ...
# 697  714      3      3             1         0     11        2       2
# 698  715      1      3             1         1      7       99       4
# 699  716      9      1             1         1     14       99       4
# 700  717      1      4             5         0      5       99       0
# 701  718      4      3             1         1     11        1       4
#
#      version  decoration  cropped_image_id
# 0          2           4                75
# 1          2           4                76
# 2          2          99                77
# 3          2           4                78
# 4          2           6                79
# ..       ...         ...               ...
# 697        2           2               745
# 698        2           2               746
# 699        2           2               747
# 700        2           2               748
# 701        2          99               749
#
# [700 rows x 11 columns]

# %%
## index 내림차순으로 정리

df = df.reset_index(drop=True)

# %%
df
# Out:
#       id  shape  strap  opening_type  material  color  pattern  handle  \
# 0     17      2      2             5         3      7       99       2
# 1     18      5      1             5         1     10       99       2
# 2     19      3      2             5         1     11       99       2
# 3     20      1      4             1         2      4        6      99
# 4     21      1      2             5         1     12       99       2
# ..   ...    ...    ...           ...       ...    ...      ...     ...
# 695  714      3      3             1         0     11        2       2
# 696  715      1      3             1         1      7       99       4
# 697  716      9      1             1         1     14       99       4
# 698  717      1      4             5         0      5       99       0
# 699  718      4      3             1         1     11        1       4
#
#      version  decoration  cropped_image_id
# 0          2           4                75
# 1          2           4                76
# 2          2          99                77
# 3          2           4                78
# 4          2           6                79
# ..       ...         ...               ...
# 695        2           2               745
# 696        2           2               746
# 697        2           2               747
# 698        2           2               748
# 699        2          99               749
#
# [700 rows x 11 columns]

# %%
df.insert(2, "filename", "NONE")

# %%
df
# Out:
#       id  shape filename  strap  opening_type  material  color  pattern  \
# 0     17      2     NONE      2             5         3      7       99
# 1     18      5     NONE      1             5         1     10       99
# 2     19      3     NONE      2             5         1     11       99
# 3     20      1     NONE      4             1         2      4        6
# 4     21      1     NONE      2             5         1     12       99
# ..   ...    ...      ...    ...           ...       ...    ...      ...
# 695  714      3     NONE      3             1         0     11        2
# 696  715      1     NONE      3             1         1      7       99
# 697  716      9     NONE      1             1         1     14       99
# 698  717      1     NONE      4             5         0      5       99
# 699  718      4     NONE      3             1         1     11        1
#
#      handle  version  decoration  cropped_image_id
# 0         2        2           4                75
# 1         2        2           4                76
# 2         2        2          99                77
# 3        99        2           4                78
# 4         2        2           6                79
# ..      ...      ...         ...               ...
# 695       2        2           2               745
# 696       4        2           2               746
# 697       4        2           2               747
# 698       0        2           2               748
# 699       4        2          99               749
#
# [700 rows x 12 columns]

# %%
is_categories_list = []
for i in range(len(df)):
    is_categories_list.append(df['cropped_image_id'][i])

# %%
len(is_categories_list)
# Out:
# 700

# %% [markdown]
# # Cropped image handling

# %%
df2 = pd.read_csv('./bag_image_csv/choco_categories_croppedimage.csv')

# %%
## category 있는 것들만 남기기

for i in range(len(df2)):
    if df2['id'][i] not in is_categories_list:
        df2 = df2.drop([i])

# %%
df2
# Out:
#        id    left     top   right  bottom  \
# 0      75  0.3966  0.1858  0.8931  1.0000
# 1      76  0.0655  0.0272  0.9759  0.9996
# 2      77  0.2034  0.0341  0.7828  0.9169
# 3      78  0.1000  0.2272  0.9138  1.0000
# 4      79  0.2241  0.0031  0.8966  0.9686
# ..    ...     ...     ...     ...     ...
# 975  1089  0.1891  0.0031  0.6254  0.9337
# 976  1090  0.2654  0.0670  0.7673  0.6920
# 977  1091  0.0618  0.3142  0.7127  0.8559
# 978  1092  0.2800  0.1031  0.8254  0.9476
# 979  1094  0.2727  0.0226  0.9018  0.9781
#
#                                     image  valid  user  origin_source_id  \
# 0    cropped-images-dev/4MIGM9TL9HF_1.jpg    1.0   3.0             10908
# 1    cropped-images-dev/9WDLPW2XG9R_1.jpg    1.0   3.0             10909
# 2    cropped-images-dev/K6G2NUNUBZE_1.jpg    1.0   3.0             10910
# 3    cropped-images-dev/KAK8GFOGQGP_1.jpg    1.0   3.0             10911
# 4    cropped-images-dev/AC84XJLNJ5S_1.jpg    1.0   3.0             10912
# ..                                    ...    ...   ...               ...
# 975  cropped-images-dev/G5YOI05KDJX_1.jpg    1.0   5.0             11180
# 976  cropped-images-dev/S3UU7PF8CUN_1.jpg    1.0   5.0             11181
# 977  cropped-images-dev/NHDQTKMEXUR_1.jpg    1.0   5.0             11182
# 978  cropped-images-dev/23U5LECOK8W_1.jpg    1.0   5.0             11183
# 979  cropped-images-dev/OPD3B9JSHFW_1.jpg    1.0   5.0             11185
#
#      Unnamed: 9  Unnamed: 10
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# ..          ...          ...
# 975         NaN          NaN
# 976         NaN          NaN
# 977         NaN          NaN
# 978         NaN          NaN
# 979         NaN          NaN
#
# [700 rows x 11 columns]

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#        id    left     top   right  bottom  \
# 0      75  0.3966  0.1858  0.8931  1.0000
# 1      76  0.0655  0.0272  0.9759  0.9996
# 2      77  0.2034  0.0341  0.7828  0.9169
# 3      78  0.1000  0.2272  0.9138  1.0000
# 4      79  0.2241  0.0031  0.8966  0.9686
# ..    ...     ...     ...     ...     ...
# 695  1089  0.1891  0.0031  0.6254  0.9337
# 696  1090  0.2654  0.0670  0.7673  0.6920
# 697  1091  0.0618  0.3142  0.7127  0.8559
# 698  1092  0.2800  0.1031  0.8254  0.9476
# 699  1094  0.2727  0.0226  0.9018  0.9781
#
#                                     image  valid  user  origin_source_id  \
# 0    cropped-images-dev/4MIGM9TL9HF_1.jpg    1.0   3.0             10908
# 1    cropped-images-dev/9WDLPW2XG9R_1.jpg    1.0   3.0             10909
# 2    cropped-images-dev/K6G2NUNUBZE_1.jpg    1.0   3.0             10910
# 3    cropped-images-dev/KAK8GFOGQGP_1.jpg    1.0   3.0             10911
# 4    cropped-images-dev/AC84XJLNJ5S_1.jpg    1.0   3.0             10912
# ..                                    ...    ...   ...               ...
# 695  cropped-images-dev/G5YOI05KDJX_1.jpg    1.0   5.0             11180
# 696  cropped-images-dev/S3UU7PF8CUN_1.jpg    1.0   5.0             11181
# 697  cropped-images-dev/NHDQTKMEXUR_1.jpg    1.0   5.0             11182
# 698  cropped-images-dev/23U5LECOK8W_1.jpg    1.0   5.0             11183
# 699  cropped-images-dev/OPD3B9JSHFW_1.jpg    1.0   5.0             11185
#
#      Unnamed: 9  Unnamed: 10
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# ..          ...          ...
# 695         NaN          NaN
# 696         NaN          NaN
# 697         NaN          NaN
# 698         NaN          NaN
# 699         NaN          NaN
#
# [700 rows x 11 columns]

# %%
## Test image 있는지 확인하기

for i in range(len(df2)):
    if df2['image'][i] == 'cropped-images-dev/0D6OZW9C9MC_1.jpg':
        print("YES")

# %% [markdown]
# ## cropped image와 category id로 matching 시키기

# %%
for i in range(len(df2)):
    for j in range(len(df)):
        if df2['id'][i] == df['cropped_image_id'][j]:
            df['filename'][j] = df2['image'][i]
# Out:
# c:\users\shimd\anaconda3\envs\mondeique\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df
# Out:
#       id  shape                              filename  strap  opening_type  \
# 0     17      2  cropped-images-dev/4MIGM9TL9HF_1.jpg      2             5
# 1     18      5  cropped-images-dev/9WDLPW2XG9R_1.jpg      1             5
# 2     19      3  cropped-images-dev/K6G2NUNUBZE_1.jpg      2             5
# 3     20      1  cropped-images-dev/KAK8GFOGQGP_1.jpg      4             1
# 4     21      1  cropped-images-dev/AC84XJLNJ5S_1.jpg      2             5
# ..   ...    ...                                   ...    ...           ...
# 695  714      3  cropped-images-dev/VKQ46JVN6UE_1.jpg      3             1
# 696  715      1  cropped-images-dev/G5HIMNIHXUH_1.jpg      3             1
# 697  716      9  cropped-images-dev/KBFCATWM6RW_1.jpg      1             1
# 698  717      1  cropped-images-dev/XIQYBVIX5KC_1.jpg      4             5
# 699  718      4  cropped-images-dev/LRCWFFTGROK_1.jpg      3             1
#
#      material  color  pattern  handle  version  decoration  cropped_image_id
# 0           3      7       99       2        2           4                75
# 1           1     10       99       2        2           4                76
# 2           1     11       99       2        2          99                77
# 3           2      4        6      99        2           4                78
# 4           1     12       99       2        2           6                79
# ..        ...    ...      ...     ...      ...         ...               ...
# 695         0     11        2       2        2           2               745
# 696         1      7       99       4        2           2               746
# 697         1     14       99       4        2           2               747
# 698         0      5       99       0        2           2               748
# 699         1     11        1       4        2          99               749
#
# [700 rows x 12 columns]

# %% [markdown]
# ## post-processing for making training csv

# %%
for i in range(len(df)):
    df['filename'][i] = './data/bag_image/' + df['filename'][i].split('/')[-1]
# Out:
# c:\users\shimd\anaconda3\envs\mondeique\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#       id  shape                            filename  strap  opening_type  \
# 0     17      2  ./data/bag_image/4MIGM9TL9HF_1.jpg      2             5
# 1     18      5  ./data/bag_image/9WDLPW2XG9R_1.jpg      1             5
# 2     19      3  ./data/bag_image/K6G2NUNUBZE_1.jpg      2             5
# 3     20      1  ./data/bag_image/KAK8GFOGQGP_1.jpg      4             1
# 4     21      1  ./data/bag_image/AC84XJLNJ5S_1.jpg      2             5
# ..   ...    ...                                 ...    ...           ...
# 695  714      3  ./data/bag_image/VKQ46JVN6UE_1.jpg      3             1
# 696  715      1  ./data/bag_image/G5HIMNIHXUH_1.jpg      3             1
# 697  716      9  ./data/bag_image/KBFCATWM6RW_1.jpg      1             1
# 698  717      1  ./data/bag_image/XIQYBVIX5KC_1.jpg      4             5
# 699  718      4  ./data/bag_image/LRCWFFTGROK_1.jpg      3             1
#
#      material  color  pattern  handle  version  decoration  cropped_image_id
# 0           3      7       99       2        2           4                75
# 1           1     10       99       2        2           4                76
# 2           1     11       99       2        2          99                77
# 3           2      4        6      99        2           4                78
# 4           1     12       99       2        2           6                79
# ..        ...    ...      ...     ...      ...         ...               ...
# 695         0     11        2       2        2           2               745
# 696         1      7       99       4        2           2               746
# 697         1     14       99       4        2           2               747
# 698         0      5       99       0        2           2               748
# 699         1     11        1       4        2          99               749
#
# [700 rows x 12 columns]

# %%
df = df.drop(columns = ['id', 'version', 'cropped_image_id'])

# %%
df
# Out:
#      shape                            filename  strap  opening_type  material  \
# 0        2  ./data/bag_image/4MIGM9TL9HF_1.jpg      2             5         3
# 1        5  ./data/bag_image/9WDLPW2XG9R_1.jpg      1             5         1
# 2        3  ./data/bag_image/K6G2NUNUBZE_1.jpg      2             5         1
# 3        1  ./data/bag_image/KAK8GFOGQGP_1.jpg      4             1         2
# 4        1  ./data/bag_image/AC84XJLNJ5S_1.jpg      2             5         1
# ..     ...                                 ...    ...           ...       ...
# 695      3  ./data/bag_image/VKQ46JVN6UE_1.jpg      3             1         0
# 696      1  ./data/bag_image/G5HIMNIHXUH_1.jpg      3             1         1
# 697      9  ./data/bag_image/KBFCATWM6RW_1.jpg      1             1         1
# 698      1  ./data/bag_image/XIQYBVIX5KC_1.jpg      4             5         0
# 699      4  ./data/bag_image/LRCWFFTGROK_1.jpg      3             1         1
#
#      color  pattern  handle  decoration
# 0        7       99       2           4
# 1       10       99       2           4
# 2       11       99       2          99
# 3        4        6      99           4
# 4       12       99       2           6
# ..     ...      ...     ...         ...
# 695     11        2       2           2
# 696      7       99       4           2
# 697     14       99       4           2
# 698      5       99       0           2
# 699     11        1       4          99
#
# [700 rows x 9 columns]

# %%
df = df[['filename','color','shape','opening_type', 'strap', 'pattern', 'material', 'handle', 'decoration']]

# %%
df
# Out:
#                                filename  color  shape  opening_type  strap  \
# 0    ./data/bag_image/4MIGM9TL9HF_1.jpg      7      2             5      2
# 1    ./data/bag_image/9WDLPW2XG9R_1.jpg     10      5             5      1
# 2    ./data/bag_image/K6G2NUNUBZE_1.jpg     11      3             5      2
# 3    ./data/bag_image/KAK8GFOGQGP_1.jpg      4      1             1      4
# 4    ./data/bag_image/AC84XJLNJ5S_1.jpg     12      1             5      2
# ..                                  ...    ...    ...           ...    ...
# 695  ./data/bag_image/VKQ46JVN6UE_1.jpg     11      3             1      3
# 696  ./data/bag_image/G5HIMNIHXUH_1.jpg      7      1             1      3
# 697  ./data/bag_image/KBFCATWM6RW_1.jpg     14      9             1      1
# 698  ./data/bag_image/XIQYBVIX5KC_1.jpg      5      1             5      4
# 699  ./data/bag_image/LRCWFFTGROK_1.jpg     11      4             1      3
#
#      pattern  material  handle  decoration
# 0         99         3       2           4
# 1         99         1       2           4
# 2         99         1       2          99
# 3          6         2      99           4
# 4         99         1       2           6
# ..       ...       ...     ...         ...
# 695        2         0       2           2
# 696       99         1       4           2
# 697       99         1       4           2
# 698       99         0       0           2
# 699        1         1       4          99
#
# [700 rows x 9 columns]

# %%
df = df.replace({'pattern' : { 99 : 15}})
df = df.replace({'decoration' : { 99 : 15}})
df = df.replace({'handle' : { 99 : 15}})

# %%
df
# Out:
#                                filename  color  shape  opening_type  strap  \
# 0    ./data/bag_image/4MIGM9TL9HF_1.jpg      7      2             5      2
# 1    ./data/bag_image/9WDLPW2XG9R_1.jpg     10      5             5      1
# 2    ./data/bag_image/K6G2NUNUBZE_1.jpg     11      3             5      2
# 3    ./data/bag_image/KAK8GFOGQGP_1.jpg      4      1             1      4
# 4    ./data/bag_image/AC84XJLNJ5S_1.jpg     12      1             5      2
# ..                                  ...    ...    ...           ...    ...
# 695  ./data/bag_image/VKQ46JVN6UE_1.jpg     11      3             1      3
# 696  ./data/bag_image/G5HIMNIHXUH_1.jpg      7      1             1      3
# 697  ./data/bag_image/KBFCATWM6RW_1.jpg     14      9             1      1
# 698  ./data/bag_image/XIQYBVIX5KC_1.jpg      5      1             5      4
# 699  ./data/bag_image/LRCWFFTGROK_1.jpg     11      4             1      3
#
#      pattern  material  handle  decoration
# 0         15         3       2           4
# 1         15         1       2           4
# 2         15         1       2          15
# 3          6         2      15           4
# 4         15         1       2           6
# ..       ...       ...     ...         ...
# 695        2         0       2           2
# 696       15         1       4           2
# 697       15         1       4           2
# 698       15         0       0           2
# 699        1         1       4          15
#
# [700 rows x 9 columns]

# %%
## export to csv

df.to_csv('./training_bag_csv', index=False)

# %%
final_df = pd.read_csv('./training_bag_csv')

# %%
final_df
# Out:
#                                filename  color  shape  opening_type  strap  \
# 0    ./data/bag_image/4MIGM9TL9HF_1.jpg      7      2             5      2
# 1    ./data/bag_image/9WDLPW2XG9R_1.jpg     10      5             5      1
# 2    ./data/bag_image/K6G2NUNUBZE_1.jpg     11      3             5      2
# 3    ./data/bag_image/KAK8GFOGQGP_1.jpg      4      1             1      4
# 4    ./data/bag_image/AC84XJLNJ5S_1.jpg     12      1             5      2
# ..                                  ...    ...    ...           ...    ...
# 695  ./data/bag_image/VKQ46JVN6UE_1.jpg     11      3             1      3
# 696  ./data/bag_image/G5HIMNIHXUH_1.jpg      7      1             1      3
# 697  ./data/bag_image/KBFCATWM6RW_1.jpg     14      9             1      1
# 698  ./data/bag_image/XIQYBVIX5KC_1.jpg      5      1             5      4
# 699  ./data/bag_image/LRCWFFTGROK_1.jpg     11      4             1      3
#
#      pattern  material  handle  decoration
# 0         15         3       2           4
# 1         15         1       2           4
# 2         15         1       2          15
# 3          6         2      15           4
# 4         15         1       2           6
# ..       ...       ...     ...         ...
# 695        2         0       2           2
# 696       15         1       4           2
# 697       15         1       4           2
# 698       15         0       0           2
# 699        1         1       4          15
#
# [700 rows x 9 columns]
